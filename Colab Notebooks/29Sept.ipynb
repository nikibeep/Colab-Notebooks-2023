# %%
import tkinter as tk
windows=tk.Tk()
window.title('Radio Button')
var=tk.StringVar()
lbl=tk.Label(window, bg='white',width=20,text='')
lb2=tk.label(window, text="what is your choice?")
lbl.pack()
lbl.pack()
def print():
  lbl.cofig

# %%
import numpy as np
import pandas as pd
data=pd.Series([0.25,0.5,0.75,1.0]) #one dimensional array of
data #
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
print(data[1])
print(data[1:3])
# Out:
# 0.5
# 1    0.50
# 2    0.75
# dtype: float64

# %%
data=pd.Series([0.25,0.5,0.75,1.0],
               index=['a','b','c','d'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data=pd.Series([0.25,0.5,0.75,1.0],
               index=[1,2,3,4])
data
# Out:
# 1    0.25
# 2    0.50
# 3    0.75
# 4    1.00
# dtype: float64

# %%
data=pd.Series([0.25,0.5,0.75,1.0],
                index=[1,2,3,4])
data[1]
print(data[1])
print(data[1:3])
# Out:
# 0.25
# 2    0.50
# 3    0.75
# dtype: float64

# %%
course_dict={'MCA':'2 years',
             'BCA':'3 years',
             'CME':'3 years',
             'MSC_CSA':'2 years'}
course=pd.Series(course_dict)
course
# Out:
# MCA        2 years
# BCA        3 years
# CME        3 years
# MSC_CSA    2 years
# dtype: object

# %%
course['MCA']
# Out:
# '2 years'

# %%
course['MCA':'BCA']
# Out:
# MCA    2 years
# BCA    3 years
# dtype: object

# %%
pd.Series(data)
# Out:
# 1    0.25
# 2    0.50
# 3    0.75
# 4    1.00
# dtype: float64

# %%
pd.Series([2,4,6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
pd.Series(5,index=[100,200,300])
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %%
pd.Series({2:'a',1:'b',3:'c'},index=[3,2,4])
# Out:
# 3      c
# 2      a
# 4    NaN
# dtype: object

# %%
pattern_dict={'MCA':'Trimester','BCA':'Semester','MSC_CSA':'Weekend','CME':'Body'}
pattern=pd.Series(pattern_dict)

# %%
details=pd.DataFrame({'Course':course,'Pattern':pattern})
details#dataframe
# Out:
#           Course    Pattern
# BCA      3 years   Semester
# CME      3 years       Body
# MCA      2 years  Trimester
# MSC_CSA  2 years    Weekend

# %%
pd.DataFrame(details,columns=['Course'])
# Out:
#           Course
# BCA      3 years
# CME      3 years
# MCA      2 years
# MSC_CSA  2 years

# %%
Dict = {1: 'banana', 2: 'apple', 3: 'Papaya'}
print("\nDictionary with the use of Integer Keys: ")
print(Dict)

# %%
f=lambda n1,n2,n3=0,n4=0: n1+2*n2+3*n3+4*n4
#f(1,2)
#f(1,2,3)
f(1,2,n4=3)
# Out:
# 17

# %%
#program to print only the ODD items from a list:
check_list={1,3,2,4,5,7,9}
new_list = list(map(lambda x:x * 2,check_list))
print(new_list)
# Out:
# [2, 4, 6, 8, 10, 14, 18]

# %%
def checkfun(n):
  return len(n)
x = map(checkfun,('Python','c','Java'))
print(x)
print(list(x))
# Out:
# ...
# [6, 1, 4]

# %%
maxlist =[27,'125',89,'100',9,0,"121",'2',10]
value=max(maxlist,key=lambda x:int(x))
print("the max value in the list:",value)
# Out:
# the max value in the list: 125

# %%
def checkfun(s1,s2):
  return s1+s2
xx=map(checkfun,{'BCA,'})
